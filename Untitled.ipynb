# %% [markdown]
# # First attempt to do an Anaconda thingy

# %%
import pandas as pd

# %%
data={"Country": ["Sweden","India", "Italy"], "Capital":["Stockholm","New Delhi","Rome"]}

# %%
data
# Out:
# {'Country': ['Sweden', 'India', 'Italy'],
#  'Capital': ['Stockholm', 'New Delhi', 'Rome']}

# %%
dataframe=pd.DataFrame(data, columns=["Country","Capital"])

# %%
dataframe
# Out:
#   Country    Capital
# 0  Sweden  Stockholm
# 1   India  New Delhi
# 2   Italy       Rome

# %%
print(dataframe)
# Out:
#   Country    Capital
# 0  Sweden  Stockholm
# 1   India  New Delhi
# 2   Italy       Rome

# %%
import numpy as np

# %%
dataframe.to_csv("first_panda.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cb41eb3e7390> in <module>()
# ----> 1 dataframe2.read_csv("first_panda.csv",header=None,nrows=5)
#
# NameError: name 'dataframe2' is not defined

# %%
dataframe2=pd.DataFrame(data,columns=["Country","Capital"])

# %%
pd.read_csv("first_panda.csv",header=None,nrows=5)
# Out:
#      0        1          2
# 0  NaN  Country    Capital
# 1  0.0   Sweden  Stockholm
# 2  1.0    India  New Delhi
# 3  2.0    Italy       Rome

# %%
pd.read_csv("tree.csv",header=None)
# Out:
#         0              1               2                3
# 0   Index   "Girth (in)"   "Height (ft)"   "Volume(ft^3)"
# 1       1            8.3              70             10.3
# 2       2            8.6              65             10.3
# 3       3            8.8              63             10.2
# 4       4           10.5              72             16.4
# 5       5           10.7              81             18.8
# 6       6           10.8              83             19.7
# 7       7             11              66             15.6
# 8       8             11              75             18.2
# 9       9           11.1              80             22.6
# 10     10           11.2              75             19.9
# 11     11           11.3              79             24.2
# 12     12           11.4              76               21
# 13     13           11.4              76             21.4
# 14     14           11.7              69             21.3
# ...

# %%
pd.read_csv("tree.csv")
# Out:
#     Index   "Girth (in)"   "Height (ft)"   "Volume(ft^3)"
# 0       1            8.3              70             10.3
# 1       2            8.6              65             10.3
# 2       3            8.8              63             10.2
# 3       4           10.5              72             16.4
# 4       5           10.7              81             18.8
# 5       6           10.8              83             19.7
# 6       7           11.0              66             15.6
# 7       8           11.0              75             18.2
# 8       9           11.1              80             22.6
# 9      10           11.2              75             19.9
# 10     11           11.3              79             24.2
# 11     12           11.4              76             21.0
# 12     13           11.4              76             21.4
# 13     14           11.7              69             21.3
# 14     15           12.0              75             19.1
# ...
